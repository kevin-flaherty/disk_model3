# %%
import disk_ecc as original
import disk_ecc_warp as mine
# Out:
# acf shape = (500, 131, 1250)
# (500, 131, 3)
# (500, 1)
# (500, 1)
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc_warp.py:328: RuntimeWarning: overflow encountered in exp
#   return np.radians(a / (1.0 + np.exp(-(r0 - r) / (0.1*dr))))
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc_warp.py:980: RuntimeWarning: divide by zero encountered in true_divide
#   theta_crit = np.arctan((self.Aout*(1+self.ecc)+tdiskY)/(self.zmax-tdiskZ))

# %%
x=original.Disk()
x.plot_structure()
# Out:
# (500, 131, 1250)
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc.py:484: RuntimeWarning: divide by zero encountered in true_divide
#   theta_crit = np.arctan((self.Aout*(1+self.ecc)+tdiskY)/(self.zmax-tdiskZ))
# self.Z shape (131, 180, 300)
# self.Z[0,:,:] shape (180, 300)
# z[0,:,:,] contents [[ 2.54316380e+15  2.52620938e+15  2.50925495e+15 ... -2.49230053e+15
#   -2.50925495e+15 -2.52620938e+15]
#  [ 2.54316380e+15  2.52620938e+15  2.50925495e+15 ... -2.49230053e+15
#   -2.50925495e+15 -2.52620938e+15]
#  [ 2.54316380e+15  2.52620938e+15  2.50925495e+15 ... -2.49230053e+15
#   -2.50925495e+15 -2.52620938e+15]
#  ...
#  [ 2.54316380e+15  2.52620938e+15  2.50925495e+15 ... -2.49230053e+15
#   -2.50925495e+15 -2.52620938e+15]
#  [ 2.54316380e+15  2.52620938e+15  2.50925495e+15 ... -2.49230053e+15
#   -2.50925495e+15 -2.52620938e+15]
#  [ 2.54316380e+15  2.52620938e+15  2.50925495e+15 ... -2.49230053e+15
#   -2.50925495e+15 -2.52620938e+15]]
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc.py:813: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[0,:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc.py:814: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[int(self.nphi/2),:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc.py:837: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[0,:,:],(20,40,60,80,100,120),colors='k',ls='--')
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc.py:838: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[int(self.nphi/2.),:,:],(20,40,60,80,100,120),colors='k',ls='--')

# %%
y=mine.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=1000.,Rc=800.,incl=2,
                 Mstar=1,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
                 handed=-1,ecc=0.,aop=0.,sigbound=[.79,1000],Rabund=[10,1000],
                 nr=150,nphi=150,nz=120,zmax=120,rtg=True,vcs=True,line='co',ring=None,w_i=0, w_r0=1e16,w_dr=1e16,w_pa=0)
# Out:
# acf shape = (500, 150, 1250)
# (500, 150, 3)
# (500, 1)
# (500, 1)
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc_warp.py:980: RuntimeWarning: divide by zero encountered in true_divide
#   theta_crit = np.arctan((self.Aout*(1+self.ecc)+tdiskY)/(self.zmax-tdiskZ))

# %%
#For some reason my r_grid is like 10^15...

# %run raytrace.py

# %%
total_model(y,imres=0.05,distance=10.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=True,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
                modfile='testpy_alma',abund=1.,obsv=None,wind=False,isgas=False,includeDust=False,extra=0,bin=1,hanning=False,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
# Out:
# With mirroring on, chanmin has been reset to put the line center in central channel
# chanstep, nchans, chanmin: 0.320, 15.000, -2.240
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-78bbd989a795> in <module>
#       1 total_model(y,imres=0.05,distance=10.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=True,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
#       2                 modfile='testpy_alma',abund=1.,obsv=None,wind=False,isgas=False,includeDust=False,extra=0,bin=1,hanning=False,
# ----> 3                 L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
#
# /Volumes/disks/theo/49ceti_warpmodel/raytrace.py in total_model(disk, imres, distance, chanmin, nchans, chanstep, flipme, Jnum, freq0, xnpix, vsys, PA, offs, modfile, abund, obsv, wind, isgas, includeDust, extra, bin, hanning, L_cloud, tau, sigma_c, velocity_c, manual_chan_params, response_function)
#     379             cube3[:,:,:,i] = tau_dust
#     380         else:
# --> 381             Inu,tau_dust = dustmodel(disk,freq0)
#     382             cube[:,:,i] = Inu
#     383             cube2[:,:,:,i] = tau_dust
#
# /Volumes/disks/theo/49ceti_warpmodel/raytrace.py in dustmodel(disk, nu)
#     133
#     134     # - Define some arrays, sizes and useful constants
# --> 135     kap = disk.kap                 # - dust opacity at 1.3mm per H2 mass [cm^2/g] (default=2.3)
#     136     BBF1 = 2.*h/(c**2)             # - prefactor for BB function
#     137     BBF2 = h/kB                    # - exponent prefactor for BB function
#
# AttributeError: 'Disk' object has no attribute 'kap'

# %%
total_model(x,imres=0.05,distance=10.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=True,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
                modfile='testpy_alma',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=False,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
# Out:
# With mirroring on, chanmin has been reset to put the line center in central channel
# chanstep, nchans, chanmin: 0.320, 15.000, -2.240

# %%
y.plot_structure(rmax=1000,zmax=200)
# Out:
# (500, 150, 1250)
# [7.59280007e+13 7.66215764e+13 7.73215827e+13 7.80280794e+13
#  7.87411266e+13 7.94607850e+13 8.01871160e+13 8.09201814e+13
#  8.16600436e+13 8.24067657e+13 8.31604113e+13 8.39210446e+13
#  8.46887303e+13 8.54635339e+13 8.62455214e+13 8.70347593e+13
#  8.78313149e+13 8.86352561e+13 8.94466513e+13 9.02655697e+13
#  9.10920809e+13 9.19262555e+13 9.27681644e+13 9.36178795e+13
#  9.44754729e+13 9.53410179e+13 9.62145882e+13 9.70962581e+13
#  9.79861027e+13 9.88841979e+13 9.97906202e+13 1.00705447e+14
#  1.01628755e+14 1.02560625e+14 1.03501135e+14 1.04450365e+14
#  1.05408397e+14 1.06375311e+14 1.07351190e+14 1.08336118e+14
#  1.09330178e+14 1.10333455e+14 1.11346034e+14 1.12368002e+14
#  1.13399445e+14 1.14440452e+14 1.15491111e+14 1.16551512e+14
#  1.17621745e+14 1.18701901e+14 1.19792073e+14 1.20892352e+14
#  1.22002834e+14 1.23123612e+14 1.24254781e+14 1.25396439e+14
#  1.26548683e+14 1.27711610e+14 1.28885320e+14 1.30069913e+14
#  1.31265489e+14 1.32472151e+14 1.33690001e+14 1.34919143e+14
#  1.36159682e+14 1.37411724e+14 1.38675374e+14 1.39950741e+14
#  1.41237934e+14 1.42537062e+14 1.43848235e+14 1.45171566e+14
#  1.46507167e+14 1.47855152e+14 1.49215636e+14 1.50588734e+14
#  1.51974565e+14 1.53373244e+14 1.54784893e+14 1.56209631e+14
#  1.57647580e+14 1.59098861e+14 1.60563600e+14 1.62041919e+14
#  1.63533947e+14 1.65039808e+14 1.66559633e+14 1.68093550e+14
#  1.69641690e+14 1.71204185e+14 1.72781167e+14 1.74372773e+14
#  1.75979136e+14 1.77600394e+14 1.79236685e+14 1.80888148e+14
#  1.82554925e+14 1.84237157e+14 1.85934987e+14 1.87648560e+14
#  1.89378023e+14 1.91123521e+14 1.92885205e+14 1.94663225e+14
#  1.96457731e+14 1.98268877e+14 2.00096816e+14 2.01941706e+14
#  2.03803702e+14 2.05682964e+14 2.07579652e+14 2.09493928e+14
#  2.11425953e+14 2.13375894e+14 2.15343916e+14 2.17330187e+14
#  2.19334876e+14 2.21358154e+14 2.23400194e+14 2.25461169e+14
#  2.27541255e+14 2.29640630e+14 2.31759472e+14 2.33897961e+14
#  2.36056281e+14 2.38234614e+14 2.40433148e+14 2.42652068e+14
#  2.44891564e+14 2.47151827e+14 2.49433050e+14 2.51735426e+14
#  2.54059153e+14 2.56404428e+14 2.58771451e+14 2.61160424e+14
#  2.63571550e+14 2.66005035e+14 2.68461087e+14 2.70939914e+14
#  2.73441728e+14 2.75966743e+14 2.78515172e+14 2.81087235e+14
#  2.83683149e+14 2.86303136e+14 2.88947420e+14 2.91616226e+14
#  2.94309781e+14 2.97028315e+14 2.99772059e+14 3.02541249e+14
#  3.05336119e+14 3.08156908e+14 3.11003856e+14 3.13877206e+14
#  3.16777204e+14 3.19704095e+14 3.22658131e+14 3.25639562e+14
#  3.28648643e+14 3.31685631e+14 3.34750784e+14 3.37844364e+14
#  3.40966634e+14 3.44117861e+14 3.47298314e+14 3.50508263e+14
#  3.53747983e+14 3.57017749e+14 3.60317841e+14 3.63648540e+14
#  3.67010130e+14 3.70402898e+14 3.73827132e+14 3.77283126e+14
#  3.80771174e+14 3.84291573e+14 3.87844624e+14 3.91430630e+14
#  3.95049897e+14 3.98702733e+14 4.02389450e+14 4.06110362e+14
#  4.09865788e+14 4.13656047e+14 4.17481464e+14 4.21342363e+14
#  4.25239075e+14 4.29171933e+14 4.33141271e+14 4.37147429e+14
#  4.41190748e+14 4.45271575e+14 4.49390256e+14 4.53547143e+14
#  4.57742592e+14 4.61976960e+14 4.66250610e+14 4.70563905e+14
#  4.74917214e+14 4.79310909e+14 4.83745365e+14 4.88220960e+14
#  4.92738078e+14 4.97297103e+14 5.01898425e+14 5.06542437e+14
#  5.11229536e+14 5.15960122e+14 5.20734599e+14 5.25553376e+14
#  5.30416863e+14 5.35325478e+14 5.40279638e+14 5.45279768e+14
#  5.50326295e+14 5.55419651e+14 5.60560270e+14 5.65748593e+14
#  5.70985062e+14 5.76270127e+14 5.81604238e+14 5.86987852e+14
#  5.92421431e+14 5.97905437e+14 6.03440342e+14 6.09026618e+14
#  6.14664743e+14 6.20355201e+14 6.26098479e+14 6.31895067e+14
#  6.37745463e+14 6.43650168e+14 6.49609687e+14 6.55624532e+14
#  6.61695216e+14 6.67822262e+14 6.74006194e+14 6.80247542e+14
#  6.86546841e+14 6.92904632e+14 6.99321461e+14 7.05797877e+14
#  7.12334437e+14 7.18931701e+14 7.25590237e+14 7.32310616e+14
#  7.39093415e+14 7.45939217e+14 7.52848611e+14 7.59822191e+14
#  7.66860556e+14 7.73964312e+14 7.81134071e+14 7.88370448e+14
#  7.95674069e+14 8.03045560e+14 8.10485559e+14 8.17994706e+14
#  8.25573648e+14 8.33223041e+14 8.40943542e+14 8.48735820e+14
#  8.56600548e+14 8.64538404e+14 8.72550076e+14 8.80636257e+14
#  8.88797645e+14 8.97034949e+14 9.05348882e+14 9.13740164e+14
#  9.22209523e+14 9.30757695e+14 9.39385422e+14 9.48093454e+14
#  9.56882549e+14 9.65753471e+14 9.74706993e+14 9.83743896e+14
#  9.92864968e+14 1.00207101e+15 1.01136281e+15 1.02074121e+15
#  1.03020700e+15 1.03976103e+15 1.04940414e+15 1.05913716e+15
#  1.06896096e+15 1.07887640e+15 1.08888436e+15 1.09898571e+15
#  1.10918136e+15 1.11947220e+15 1.12985915e+15 1.14034312e+15
#  1.15092506e+15 1.16160591e+15 1.17238661e+15 1.18326813e+15
#  1.19425145e+15 1.20533755e+15 1.21652744e+15 1.22782211e+15
#  1.23922259e+15 1.25072991e+15 1.26234511e+15 1.27406927e+15
#  1.28590343e+15 1.29784869e+15 1.30990615e+15 1.32207692e+15
#  1.33436211e+15 1.34676287e+15 1.35928036e+15 1.37191574e+15
#  1.38467019e+15 1.39754493e+15 1.41054116e+15 1.42366012e+15
#  1.43690307e+15 1.45027127e+15 1.46376601e+15 1.47738861e+15
#  1.49114038e+15 1.50502269e+15 1.51903689e+15 1.53318438e+15
#  1.54746658e+15 1.56188492e+15 1.57644087e+15 1.59113592e+15
#  1.60597158e+15 1.62094940e+15 1.63607094e+15 1.65133782e+15
#  1.66675166e+15 1.68231413e+15 1.69802693e+15 1.71389180e+15
#  1.72991052e+15 1.74608489e+15 1.76241676e+15 1.77890805e+15
#  1.79556070e+15 1.81237668e+15 1.82935806e+15 1.84650691e+15
#  1.86382541e+15 1.88131575e+15 1.89898021e+15 1.91682113e+15
#  1.93484092e+15 1.95304207e+15 1.97142713e+15 1.98999877e+15
#  2.00875970e+15 2.02771277e+15 2.04686091e+15 2.06620714e+15
#  2.08575463e+15 2.10550664e+15 2.12546657e+15 2.14563798e+15
#  2.16602454e+15 2.18663010e+15 2.20745867e+15 2.22851446e+15
#  2.24980184e+15 2.27132541e+15 2.29308999e+15 2.31510064e+15
#  2.33736267e+15 2.35988167e+15 2.38266352e+15 2.40571442e+15
#  2.42904092e+15 2.45264992e+15 2.47654875e+15 2.50074512e+15
#  2.52524725e+15 2.55006383e+15 2.57520408e+15 2.60067782e+15
#  2.62649549e+15 2.65266819e+15 2.67920776e+15 2.70612685e+15
#  2.73343892e+15 2.76115838e+15 2.78930065e+15 2.81788219e+15
#  2.84692066e+15 2.87643497e+15 2.90644541e+15 2.93697374e+15
#  2.96804333e+15 2.99967929e+15 3.03190859e+15 3.06476026e+15
#  3.09826550e+15 3.13245792e+15 3.16737368e+15 3.20305174e+15
#  3.23953404e+15 3.27686579e+15 3.31509570e+15 3.35427623e+15
#  3.39446394e+15 3.43571974e+15 3.47810924e+15 3.52170311e+15
#  3.56657741e+15 3.61281397e+15 3.66050079e+15 3.70973241e+15
#  3.76061033e+15 3.81324341e+15 3.86774822e+15 3.92424947e+15
#  3.98288033e+15 4.04378272e+15 4.10710761e+15 4.17301516e+15
#  4.24167481e+15 4.31326526e+15 4.38797425e+15 4.46599821e+15
#  4.54754165e+15 4.63281626e+15 4.72203979e+15 4.81543445e+15
#  4.91322496e+15 5.01563612e+15 5.12288988e+15 5.23520177e+15
#  5.35277686e+15 5.47580498e+15 5.60445537e+15 5.73887075e+15
#  5.87916086e+15 6.02539552e+15 6.17759749e+15 6.33573525e+15
#  6.49971597e+15 6.66937905e+15 6.84449056e+15 7.02473905e+15
#  7.20973312e+15 7.39900124e+15 7.59199416e+15 7.78809027e+15
#  7.98660409e+15 8.18679782e+15 8.38789590e+15 8.58910211e+15
#  8.78961858e+15 8.98866596e+15 9.18550369e+15 9.37944944e+15
#  9.56989660e+15 9.75632898e+15 9.93833179e+15 1.01155985e+16
#  1.02879335e+16 1.04552499e+16 1.06175644e+16 1.07749875e+16
#  1.09277121e+16 1.10760002e+16 1.12201677e+16 1.13605710e+16
#  1.14975920e+16 1.16316263e+16 1.17630714e+16 1.18923173e+16
#  1.20197395e+16 1.21456928e+16 1.22705076e+16 1.23944873e+16
#  1.25179073e+16 1.26410150e+16 1.27640304e+16 1.28871477e+16
#  1.30105368e+16 1.31343456e+16 1.32587022e+16 1.33837169e+16
#  1.35094844e+16 1.36360861e+16 1.37635915e+16 1.38920601e+16
#  1.40215431e+16 1.41520845e+16 1.42837223e+16 1.44164896e+16
#  1.45504156e+16 1.46855258e+16 1.48218434e+16 1.49593892e+16]

# %%
from astropy.io import fits

# %%
unwarped = fits.open('testpy_alma.fits')
unwarped.info()
# Out:
# Filename: testpy_alma.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (512, 512, 15)   float64

# %%
og_with_params = original.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=1000.,Rc=150.,incl=5,
                 Mstar=1,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
                 handed=-1,ecc=.5,aop=0.,sigbound=[.79,1000],Rabund=[10,800],
                 nr=180,nphi=131,nz=300,zmax=170,rtg=True,vcs=True,line='co',ring=None)
# Out:
# (500, 131, 1250)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-baa3cc237e04> in <module>
#       2                  Mstar=1,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
#       3                  handed=-1,ecc=.5,aop=0.,sigbound=[.79,1000],Rabund=[10,800],
# ----> 4                  nr=180,nphi=131,nz=300,zmax=170,rtg=True,vcs=True,line='co',ring=None)
#
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py in __init__(self, q, McoG, pp, Ain, Aout, Rc, incl, Mstar, Xco, vturb, Zq0, Tmid0, Tatm0, handed, ecc, aop, sigbound, Rabund, nr, nphi, nz, zmax, rtg, vcs, line, ring)
#      65         self.set_params(params) # set the structure parameters
#      66
# ---> 67         self.set_structure()  # use obs and params to create disk structure
#      68         if rtg:
#      69             self.set_rt_grid()
#
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py in set_structure(self)
#     372                 foo[0] = 0
#     373                 nsl = foo.cumsum()
# --> 374                 sig_col[ia,jf,:] = nsl[::-1]*Disk.m0/Disk.Hnuctog
#     375                 pht = (np.abs(nsl) >= self.sigbound[0])
#     376                 if pht.sum() == 0:
#
# KeyboardInterrupt:

# %%
'''
z=mine.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=100.,Rc=80.,incl=1,
                 Mstar=1,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
                 handed=-1,ecc=0.,aop=0.,sigbound=[.79,100],Rabund=[10,100],
                 nr=50,nphi=50,nz=20,zmax=170,rtg=True,vcs=True,line='co',ring=None,w_i=0, w_r0=1e15,w_dr=1e15,w_pa=0)

'''
# Out:
# "\nz=mine.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=100.,Rc=80.,incl=1,\n                 Mstar=1,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,\n                 handed=-1,ecc=0.,aop=0.,sigbound=[.79,100],Rabund=[10,100],\n                 nr=50,nphi=50,nz=20,zmax=170,rtg=True,vcs=True,line='co',ring=None,w_i=0, w_r0=1e15,w_dr=1e15,w_pa=0)\n\n"

# %%
z.plot_structure(rmax=110,zmax=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6a06a639ff84> in <module>
# ----> 1 z.plot_structure(rmax=110,zmax=100)
#
# NameError: name 'z' is not defined

# %%
og_with_params.plot_structure()
# Out:
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py:809: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[0,:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py:810: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[int(self.nphi/2),:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py:833: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[0,:,:],(20,40,60,80,100,120),colors='k',ls='--')
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py:834: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[int(self.nphi/2.),:,:],(20,40,60,80,100,120),colors='k',ls='--')

# %%
mine_with_params = mine.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=1000.,Rc=150.,incl=1,
                 Mstar=2.3,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
                 handed=-1,ecc=0.,aop=0.,sigbound=[.79,1000],Rabund=[10,800],
                 nr=180,nphi=131,nz=300,zmax=170,rtg=True,vcs=True,line='co',ring=None,w_i=0, w_r0=1e14,w_dr=1e14,w_pa=60)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cb8be7cb260d> in <module>
# ----> 1 mine_with_params = mine.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=1000.,Rc=150.,incl=1,
#       2                  Mstar=2.3,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
#       3                  handed=-1,ecc=0.,aop=0.,sigbound=[.79,1000],Rabund=[10,800],
#       4                  nr=180,nphi=131,nz=300,zmax=170,rtg=True,vcs=True,line='co',ring=None,w_i=0, w_r0=1e14,w_dr=1e14,w_pa=60)
#
# NameError: name 'mine' is not defined

# %%
mine_with_params.plot_structure(rmax=200, zmax=10)

# %%
run raytrace.py
