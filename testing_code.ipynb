# %%
from disk_ecc import *

# %%
y=Disk()
# Out:
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py:483: RuntimeWarning: divide by zero encountered in true_divide
#   theta_crit = np.arctan((self.Aout*(1+self.ecc)+tdiskY)/(self.zmax-tdiskZ))

# %%
y.plot_structure()
# Out:
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py:809: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[0,:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py:810: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[int(self.nphi/2),:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py:833: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[0,:,:],(20,40,60,80,100,120),colors='k',ls='--')
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py:834: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[int(self.nphi/2.),:,:],(20,40,60,80,100,120),colors='k',ls='--')

# %%
from disk_ecc_warp import *
# Out:
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc_warp.py:869: RuntimeWarning: divide by zero encountered in true_divide
#   theta_crit = np.arctan((self.Aout*(1+self.ecc)+tdiskY)/(self.zmax-tdiskZ))

# %%
x=Disk(params=[-0.5,0.09,1.,10.,1000.,150.,51.5,2.3,1e-4,0.01,33.9,19.,69.3,-1,0.,0.,[.79,1000],[10,800], 10, 10,10,10])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-f51ede982d83> in <module>
# ----> 1 x=Disk(params=[-0.5,0.09,1.,10.,1000.,150.,51.5,2.3,1e-4,0.01,33.9,19.,69.3,-1,0.,0.,[.79,1000],[10,800], 10, 10,10,10])
#
# TypeError: __init__() got an unexpected keyword argument 'params'

# %%
import disk as disk_

# %%
y=disk_.Disk()
# Out:
# /Volumes/disks/theo/49ceti_warpmodel/disk.py:209: RuntimeWarning: invalid value encountered in sqrt
#   Omg = np.sqrt((dPdr/(rcf*self.rho0)+Disk.G*self.Mstar/(rcf**2+zcf**2)**1.5))
# /Volumes/disks/theo/49ceti_warpmodel/disk.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   theta_crit = np.arctan((self.Rout+tdiskY)/(self.zmax-tdiskZ))

# %%
y.plot_structure()
# Out:
# /Volumes/disks/theo/49ceti_warpmodel/disk.py:624: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10((self.rhoG/self.Xmol)[0,:,:]),np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/disk.py:626: RuntimeWarning: divide by zero encountered in log10
#   cs3 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.sig_col[0,:,:]),(-2,-1),linestyles=':',linewidths=3,colors='k')
# /Volumes/disks/theo/49ceti_warpmodel/disk.py:626: RuntimeWarning: invalid value encountered in log10
#   cs3 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.sig_col[0,:,:]),(-2,-1),linestyles=':',linewidths=3,colors='k')

# %%
y = disk_.Disk(params=[-0.529,0.119,1.,10.,1000.,135.6,51.5,2.3,1e-4,0.081,70.,17.5,94.,[.79,1000],[50,500],-1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-591e9b7e3780> in <module>
# ----> 1 y = disk_.Disk(params=[-0.529,0.119,1.,10.,1000.,135.6,51.5,2.3,1e-4,0.081,70.,17.5,94.,[.79,1000],[50,500],-1])
#       2
#
# TypeError: __init__() got an unexpected keyword argument 'params'

# %%
# %matplotlib inline
x.plot_structure()
# Out:
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc_warp.py:1195: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[0,:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc_warp.py:1196: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[int(self.nphi/2),:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc_warp.py:1219: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[0,:,:],(20,40,60,80,100,120),colors='k',ls='--')
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc_warp.py:1220: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[int(self.nphi/2.),:,:],(20,40,60,80,100,120),colors='k',ls='--')
